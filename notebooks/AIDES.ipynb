# %%
import csv
import requests
import pandas as pd
import xlrd

# %%
headers = {'Accept': 'application/json','Authorization': 'Bearer 5f0f5f31-c246-3903-9ae7-a9b81006001d'}
#croisement="NA5_B-ENTR_INDIVIDUELLE"
#jeu_donnees="GEO2017REE2017"
#nivgeo="COM"

#codgeo="51108"
#modalite="all.all"
url='https://api.insee.fr/donnees-locales/V0.1/donnees/geo-NA5_B-ENTR_INDIVIDUELLE@GEO2017REE2017/COM-51108.all.all'
#url =f'https://api.insee.fr/donnees-locales/V0.1/donnees/geo-{croisement}@{jeu_donnees}/{nivgeo}-{codgeo}.{modalite}'
response=requests.get(url,headers=headers).json()

# %%
df = pd.read_excel('raw_data/diffusion-zonages-afr-cog2021.xls')
df.columns = ['codepostal','nom','statut']
df = df.drop(df.index[[0,1,2,3,4]])
df['dep']= df[str('codepostal')]
df = df.reset_index()
df
# Out:
#        index codepostal                      nom  \
# 0          5      01001  L'Abergement-Clémenciat
# 1          6      01002    L'Abergement-de-Varey
# 2          7      01004        Ambérieu-en-Bugey
# 3          8      01005      Ambérieux-en-Dombes
# 4          9      01006                  Ambléon
# ...      ...        ...                      ...
# 34960  34965      97613            M'Tsangamouji
# 34961  34966      97614                 Ouangani
# 34962  34967      97615                 Pamandzi
# 34963  34968      97616                     Sada
# 34964  34969      97617                 Tsingoni
#
#                                  statut    dep
# 0                     NC - Non éligible  01001
# 1                     NC - Non éligible  01002
# 2                     NC - Non éligible  01004
# 3                     NC - Non éligible  01005
# 4                     NC - Non éligible  01006
# ...                                 ...    ...
# ...

# %%
for x in df['dep']:
    print(''.join(list(x)[0:2]))
# Out:
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# 01
# ...

# %%
for x in range(len(df['dep'])):
    df['dep'].iloc[x] = (''.join(list(df['dep'][x])[0:2]))
    
df
# Out:
# /var/folders/qm/r5y57t3x2_l2s8zdf4jhsbgc0000gn/T/ipykernel_56855/1404395780.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dep'].iloc[x] = (''.join(list(df['dep'][x])[0:2]))
#        index codepostal                      nom  \
# 0          5      01001  L'Abergement-Clémenciat
# 1          6      01002    L'Abergement-de-Varey
# 2          7      01004        Ambérieu-en-Bugey
# 3          8      01005      Ambérieux-en-Dombes
# 4          9      01006                  Ambléon
# ...      ...        ...                      ...
# 34960  34965      97613            M'Tsangamouji
# 34961  34966      97614                 Ouangani
# 34962  34967      97615                 Pamandzi
# 34963  34968      97616                     Sada
# 34964  34969      97617                 Tsingoni
#
# ...

# %%
df2 = df.drop(columns = 'codepostal')
df2
for x in range(len(df2['statut'])): 
    if df2['statut'].iloc[x] == 'NC - Non éligible': 
        df2['statut'].iloc[x] = 0
    else : 
        df2['statut'].iloc[x] = 1

df2
# Out:
#                            nom statut dep
# 0      L'Abergement-Clémenciat      0  01
# 1        L'Abergement-de-Varey      0  01
# 2            Ambérieu-en-Bugey      0  01
# 3          Ambérieux-en-Dombes      0  01
# 4                      Ambléon      0  01
# ...                        ...    ...  ..
# 34960            M'Tsangamouji      1  97
# 34961                 Ouangani      1  97
# 34962                 Pamandzi      1  97
# 34963                     Sada      1  97
# 34964                 Tsingoni      1  97
#
# [34965 rows x 3 columns]

# %%
count = df2.groupby('dep').sum()
count.sort_values(by = 'statut', ascending=False).drop(columns = 'nom')
# Out:
#      statut
# dep
# 2B      236
# 59      207
# 02      161
# 62      159
# 97      129
# ..      ...
# 74        0
# 69        0
# 67        0
# 38        0
# 01        0
#
# [97 rows x 1 columns]
