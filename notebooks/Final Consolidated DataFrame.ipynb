# %%
import pandas as pd

# %%
df=pd.read_csv('../raw_data/cities.csv')
df
# Out:
#       code_commune_INSEE       nom_commune_postal  code_postal  \
# 0                   1001  L ABERGEMENT CLEMENCIAT         1400
# 1                   1002    L ABERGEMENT DE VAREY         1640
# 2                   1004        AMBERIEU EN BUGEY         1500
# 3                   1005      AMBERIEUX EN DOMBES         1330
# 4                   1006                  AMBLEON         1300
# ...                  ...                      ...          ...
# 39196              98831                      VOH        98883
# 39197              98832                     YATE        98834
# 39198              98833                  KOUAOUA        98818
# 39199              98901        ILE DE CLIPPERTON        98799
# 39200              99138                   MONACO        98000
#
#           libelle_acheminement ligne_5   latitude  longitude  code_commune  \
# 0      L ABERGEMENT CLEMENCIAT     NaN  46.153426   4.926114           1.0
# ...

# %%
df=df[['code_commune_INSEE','code_postal','latitude','longitude','nom_commune_complet','code_departement','nom_departement','code_region','nom_region']]

# %%
df[(df == 73550).any(axis=1)]
# Out:
#       code_commune_INSEE  code_postal   latitude  longitude  \
# 31976              73015        73550  45.369715   6.587679
# 31977              73015        73550  45.369715   6.587679
#
#       nom_commune_complet code_departement nom_departement  code_region  \
# 31976          Les Allues               73          Savoie         84.0
# 31977          Les Allues               73          Savoie         84.0
#
#                  nom_region
# 31976  Auvergne-Rhône-Alpes
# 31977  Auvergne-Rhône-Alpes

# %%
df=df.drop_duplicates()

# %%
df[(df.isna()).any(axis=1)]
# Out:
#       code_commune_INSEE  code_postal  latitude  longitude  \
# 38911              97501        97500       NaN        NaN
# 38913              97502        97500       NaN        NaN
# 38937              97701        97133       NaN        NaN
# 38938              97801        97150       NaN        NaN
# 38939              98611        98610       NaN        NaN
# ...                  ...          ...       ...        ...
# 39196              98831        98883       NaN        NaN
# 39197              98832        98834       NaN        NaN
# 39198              98833        98818       NaN        NaN
# 39199              98901        98799       NaN        NaN
# 39200              99138        98000       NaN        NaN
#
#       nom_commune_complet code_departement nom_departement  code_region  \
# 38911   Miquelon langlade               97             NaN          NaN
# 38913           St pierre               97             NaN          NaN
# ...

# %%
df.dropna(subset=['nom_departement'],inplace=True)
df.reset_index(inplace=True)

# %%
pop=pd.read_excel('../raw_data/pop.xls')
pop
# Out:
#       CODGEO  Nb Pharmacies et parfumerie  Dynamique Entrepreneuriale  \
# 0      01001                          0.0                        57.0
# 1      01002                          0.0                        45.0
# 2      01004                          0.0                       634.0
# 3      01005                          0.0                       113.0
# 4      01006                          0.0                        42.0
# ...      ...                          ...                         ...
# 36672  97420                          0.0                       657.0
# 36673  97421                          0.0                       228.0
# 36674  97422                          0.0                      2689.0
# 36675  97423                          0.0                       222.0
# 36676  97424                          0.0                       163.0
#
#        Dynamique Entrepreneuriale Service et Commerce  \
# 0                                                23.0
# ...

# %%
pop.rename(columns={'CODGEO':'code_commune_INSEE'},inplace=True)

# %%
pop=pop[['code_commune_INSEE','Population']]

# %%
pop
# Out:
#       code_commune_INSEE  Population
# 0                  01001         725
# 1                  01002         167
# 2                  01004       11432
# 3                  01005        1407
# 4                  01006          86
# ...                  ...         ...
# 36672              97420       18137
# 36673              97421        7400
# 36674              97422       60311
# 36675              97423        6597
# 36676              97424        6115
#
# [36677 rows x 2 columns]

# %%
for x in range(len(df['code_commune_INSEE'])):
    if len(df['code_commune_INSEE'][x])<5:
        y='0'+str(df['code_commune_INSEE'][x])
        df['code_commune_INSEE'].iloc[x]=y
# Out:
# /tmp/ipykernel_12280/3099425176.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['code_commune_INSEE'].iloc[x]=y

# %%
df=df.merge(pop,on='code_commune_INSEE',how='left')
df
# Out:
#        index code_commune_INSEE  code_postal   latitude  longitude  \
# 0          0              01001         1400  46.153426   4.926114
# 1          1              01002         1640  46.009188   5.428017
# 2          2              01004         1500  45.960848   5.372926
# 3          3              01005         1330  45.996180   4.912273
# 4          4              01006         1300  45.749499   5.594320
# ...      ...                ...          ...        ...        ...
# 36213  38931              97613        97650 -12.751310  45.087170
# 36214  38932              97614        97670 -12.837096  45.137910
# 36215  38934              97615        97615 -12.796135  45.284206
# 36216  38935              97616        97640 -12.861165  45.118550
# 36217  38936              97617        97680 -12.782167  45.134428
#
#            nom_commune_complet code_departement nom_departement  code_region  \
# 0      L'Abergement-Clémenciat                1             Ain         84.0
# ...

# %%
df[(df.isna()).any(axis=1)]
# Out:
#        index code_commune_INSEE  code_postal   latitude  longitude  \
# 4506    4834              13201        13001  43.299901   5.382279
# 4507    4835              13202        13002  43.312696   5.363650
# 4508    4836              13203        13003  43.312120   5.380110
# 4509    4837              13204        13004  43.306733   5.400875
# 4510    4838              13205        13005  43.292806   5.397577
# ...      ...                ...          ...        ...        ...
# 36213  38931              97613        97650 -12.751310  45.087170
# 36214  38932              97614        97670 -12.837096  45.137910
# 36215  38934              97615        97615 -12.796135  45.284206
# 36216  38935              97616        97640 -12.861165  45.118550
# 36217  38936              97617        97680 -12.782167  45.134428
#
#       nom_commune_complet code_departement   nom_departement  code_region  \
# 4506         Marseille 01               13  Bouches-du-Rhône         93.0
# ...

# %%
df[(df == 75001).any(axis=1)]
# Out:
#        index code_commune_INSEE  code_postal  latitude  longitude  \
# 30327  32613              75101        75001  48.86263   2.336293
#
#       nom_commune_complet code_departement nom_departement  code_region  \
# 30327            Paris 01               75           Paris         11.0
#
#           nom_region  Population
# 30327  Île-de-France         NaN
