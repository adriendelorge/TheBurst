# %%
import csv
import requests
import pandas as pd
import numpy as np
import xlrd

# %%
df = pd.read_csv('raw_data/meta_base-cc-demo-entreprises-2020.csv', sep = ';')

df
# Out:
#         COD_VAR                                            LIB_VAR  \
# 0      ENNTOT20                 Unités légales au 31 décembre 2019
# 1       ENNBE20  Unités légales de l'industrie au 31 décembre 2019
# 2       ENNFZ20  Unités légales de la construction au 31 décemb...
# 3       ENNGI20  Unités légales de commerce, transp, restau, hé...
# 4       ENNJZ20  Unités légales d’information et communication ...
# ...         ...                                                ...
# 35163    CODGEO                                  Code géographique
# 35164    CODGEO                                  Code géographique
# 35165    CODGEO                                  Code géographique
# 35166    CODGEO                                  Code géographique
# 35167    CODGEO                                  Code géographique
#
#                                             LIB_VAR_LONG COD_MOD  \
# 0                     Unités légales au 31 décembre 2019     NaN
# ...
